# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('national_generation_capacity_stacked.csv')

# %%
data=df1[df1.country.isin(['DE','FR'])]

# %%
wblinks=data.weblink

# %%
data.drop(columns=['weblink'],inplace=True)
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20332\1698080622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['weblink'],inplace=True)

# %%
data.capacity_definition.value_counts()
# Out:
# Unknown         1158
# Net capacity     733
# Name: capacity_definition, dtype: int64

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns=['index'],inplace=True)
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20332\2136747082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['index'],inplace=True)

# %%
data1=data

# %%
data1.drop(columns=['source','source_type','capacity_definition','comment'],inplace=True)
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20332\228924561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(columns=['source','source_type','capacity_definition','comment'],inplace=True)

# %%
data1=data1.sort_values(by=['year'])

# %%
france=data1[data1['country']=='FR']
germany=data1[data1['country']=='DE']

# %%
france.capacity.value_counts()
# Out:
# 0.0         229
# 63130.0      32
# 240.0        25
# 2.0          14
# 6121.0        8
#            ...
# 1194.0        1
# 32977.0       1
# 123510.0      1
# 7641.0        1
# 246.0         1
# Name: capacity, Length: 520, dtype: int64

# %%
data1[data1.country=='DE']
# Out:
#        ID                           technology  year  \
# 140  3599  Other bioenergy and renewable waste  1990
# 132  3591                   Biomass and biogas  1990
# 133  3592             Concentrated solar power  1990
# 134  3593                         Fossil fuels  1990
# 135  3594                           Geothermal  1990
# ..    ...                                  ...   ...
# 626  4085                   Biomass and biogas  2016
# 636  4095                       Pumped storage  2016
# 627  4086             Concentrated solar power  2016
# 628  4087                         Fossil fuels  2016
# 635  4094                        Photovoltaics  2016
#
#                          type country  capacity  energy_source_level_0  \
# 140  Installed capacity in MW      DE      22.0                  False
# 132  Installed capacity in MW      DE      89.0                  False
# 133  Installed capacity in MW      DE       0.0                  False
# ...

# %%
germany=germany[germany.capacity>0.0]
france=france[france.capacity>0.0]

# %%
france.drop(columns=['energy_source_level_0','energy_source_level_1','energy_source_level_2','energy_source_level_3'],inplace=True)
germany.drop(columns=['energy_source_level_0','energy_source_level_1','energy_source_level_2','energy_source_level_3'],inplace=True)

# %%
france
# Out:
#        ID                            technology  year  \
# 661  6172              Renewable energy sources  1990
# 655  6166                        Pumped storage  1990
# 652  6163                               Nuclear  1990
# 650  6161                                Marine  1990
# 662  6173  Differently categorized fossil fuels  1990
# ..    ...                                   ...   ...
# 76   1083                                  Wind  2020
# 101  1463         Differently categorized solar  2020
# 50    775                                 Hydro  2020
# 117  1601                    Biomass and biogas  2020
# 107  1524                                Marine  2020
#
#                          type country  capacity  technology_level
# 661  Installed capacity in MW      FR   24913.0             False
# 655  Installed capacity in MW      FR    1792.0              True
# 652  Installed capacity in MW      FR   55750.0              True
# ...

# %%
germany.technology.value_counts()
# Out:
# Fossil fuels                                        38
# Nuclear                                             38
# Wind                                                38
# Solar                                               38
# Renewable energy sources                            38
# Total                                               38
# Hydro                                               38
# Bioenergy and renewable waste                       36
# Biomass and biogas                                  36
# Differently categorized wind                        33
# Differently categorized fossil fuels                33
# Pumped storage                                      28
# Other bioenergy and renewable waste                 27
# Non-renewable waste                                 27
# Photovoltaics                                       27
# Differently categorized solar                       11
# Geothermal                                          10
# ...
